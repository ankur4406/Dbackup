# %%
import cv2
import matplotlib.pyplot as plt
import os
from scipy import misc

# %%
dir = r'C:\Users\ankuarora\Desktop\Client\2017_05_CogEx\2017_07_R2Implementation\Sprint 5_fix\1reference_config_creation'
img_form = 'full_output.png'

# %%
form = cv2.imread(os.path.join(dir,img_form))
form_gray = cv2.cvtColor(form,cv2.COLOR_BGR2GRAY)
form_gray = cv2.GaussianBlur(form_gray,(5,5),0)
plt.imshow(form_gray), plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x1f0f082ee10>, None)

# %%
# Identify Label (update x1, x2, y1, y2)
misc.toimage(form_gray[4805:4830,50:360])
# Out:
# <PIL.Image.Image image mode=L size=310x25 at 0x1F0F0803EF0>

# %%
# Identify Value
misc.toimage(form_gray[5700:5730,50:350])
# Out:
# <PIL.Image.Image image mode=L size=300x30 at 0x1F08A2D4CC0>

# %%
misc.toimage(form_gray[4850:5650,50:1640])
# Out:
# <PIL.Image.Image image mode=L size=1590x800 at 0x1F08A2ED6D8>
